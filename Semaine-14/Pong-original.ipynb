# %%
""" Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym. """
import numpy as np
import _pickle as pickle
import gym

# hyperparameters
H = 200 # number of hidden layer neurons
batch_size = 10 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?
render = True

# model initialization
D = 80 * 80 # input dimensionality: 80x80 grid
if resume:
  model = pickle.load(open('save.p', 'rb'))
else:
  model = {}
  model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
  model['W2'] = np.random.randn(H) / np.sqrt(H)
  
grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  return I.astype(np.float).ravel()

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(range(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

def policy_backward(eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

env = gym.make("Pong-v0")
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0
while True:
  if render: env.render()

  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)
  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  prev_x = cur_x

  # forward the policy network and sample an action from the returned probability
  aprob, h = policy_forward(x)
  action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

  # record various intermediates (needed later for backprop)
  xs.append(x) # observation
  hs.append(h) # hidden state
  y = 1 if action == 2 else 0 # a "fake label"
  dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

  # step the environment and get new measurements
  observation, reward, done, info = env.step(action)
  reward_sum += reward

  drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

  if done: # an episode finished
    episode_number += 1

    # stack together all inputs, hidden states, action gradients, and rewards for this episode
    epx = np.vstack(xs)
    eph = np.vstack(hs)
    epdlogp = np.vstack(dlogps)
    epr = np.vstack(drs)
    xs,hs,dlogps,drs = [],[],[],[] # reset array memory

    # compute the discounted reward backwards through time
    discounted_epr = discount_rewards(epr)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_epr -= np.mean(discounted_epr)
    discounted_epr /= np.std(discounted_epr)

    epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
    grad = policy_backward(eph, epdlogp)
    for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

    # perform rmsprop parameter update every batch_size episodes
    if episode_number % batch_size == 0:
      for k,v in model.items():
        g = grad_buffer[k] # gradient
        rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
        model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
        grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

    # boring book-keeping
    running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
    print('resetting env. episode reward total was %f. running mean: %f', reward_sum, running_reward)
    if episode_number % 100 == 0: pickle.dump(model, open('save.p', 'wb'))
    reward_sum = 0
    observation = env.reset() # reset env
    prev_x = None

  if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
    print('ep %d: game finished, reward: %f', episode_number, reward, '' if reward == -1 else ' !!!!!!!!')
# Out:
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# ep %d: game finished, reward: %f 0 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -21.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# ep %d: game finished, reward: %f 1 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.99
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# ep %d: game finished, reward: %f 2 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.990099999999998
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# ep %d: game finished, reward: %f 3 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.980199
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 4 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# ep %d: game finished, reward: %f 4 -1.0
# resetting env. episode reward total was %f. running mean: %f -18.0 -20.95039701
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# ep %d: game finished, reward: %f 5 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.9508930399
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# ep %d: game finished, reward: %f 6 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.951384109501
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# ep %d: game finished, reward: %f 7 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.95187026840599
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# ep %d: game finished, reward: %f 8 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.93235156572193
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# ep %d: game finished, reward: %f 9 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.933028050064713
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# ep %d: game finished, reward: %f 10 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.933697769564066
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 11 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# ep %d: game finished, reward: %f 11 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.914360791868425
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# ep %d: game finished, reward: %f 12 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.895217183949743
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# ep %d: game finished, reward: %f 13 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.886265012110243
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# ep %d: game finished, reward: %f 14 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.887402361989142
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# ep %d: game finished, reward: %f 15 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.88852833836925
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 -1.0
# ep %d: game finished, reward: %f 16 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 16 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.86964305498556
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# ep %d: game finished, reward: %f 17 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.8609466244357
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# ep %d: game finished, reward: %f 18 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.862337158191345
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# ep %d: game finished, reward: %f 19 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.85371378660943
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# ep %d: game finished, reward: %f 20 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.855176648743335
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 -1.0
# ep %d: game finished, reward: %f 21 1.0  !!!!!!!!
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.8466248822559
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# ep %d: game finished, reward: %f 22 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.84815863343334
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# ep %d: game finished, reward: %f 23 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.849677047099007
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# ep %d: game finished, reward: %f 24 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.851180276628018
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# ep %d: game finished, reward: %f 25 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.842668473861735
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# ep %d: game finished, reward: %f 26 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.844241789123117
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 -1.0
# ep %d: game finished, reward: %f 27 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 27 1.0  !!!!!!!!
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.825799371231888
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# ep %d: game finished, reward: %f 28 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.82754137751957
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# ep %d: game finished, reward: %f 29 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.829265963744373
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# ep %d: game finished, reward: %f 30 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.83097330410693
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# ep %d: game finished, reward: %f 31 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.83266357106586
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# ep %d: game finished, reward: %f 32 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.824336935355202
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# ep %d: game finished, reward: %f 33 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.816093566001648
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# ep %d: game finished, reward: %f 34 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.81793263034163
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# ep %d: game finished, reward: %f 35 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.819753304038215
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# ep %d: game finished, reward: %f 36 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.821555770997833
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# ep %d: game finished, reward: %f 37 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.823340213287857
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 -1.0
# ep %d: game finished, reward: %f 38 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 38 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.815106811154976
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# ep %d: game finished, reward: %f 39 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.806955743043424
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# ep %d: game finished, reward: %f 40 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.80888618561299
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# ep %d: game finished, reward: %f 41 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.790797323756863
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 -1.0
# ep %d: game finished, reward: %f 42 1.0  !!!!!!!!
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.782889350519294
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# ep %d: game finished, reward: %f 43 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.7750604570141
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# ep %d: game finished, reward: %f 44 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.77730985244396
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# ep %d: game finished, reward: %f 45 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.77953675391952
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# ep %d: game finished, reward: %f 46 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.771741386380324
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# ep %d: game finished, reward: %f 47 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.77402397251652
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ep %d: game finished, reward: %f 48 -1.0
# ...
# ep %d: game finished, reward: %f 929 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.394053070641974
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# ep %d: game finished, reward: %f 930 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.390112539935554
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# ep %d: game finished, reward: %f 931 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.3962114145362
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# ep %d: game finished, reward: %f 932 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.40224930039084
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# ep %d: game finished, reward: %f 933 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.40822680738693
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# ep %d: game finished, reward: %f 934 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.414144539313064
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# ep %d: game finished, reward: %f 935 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.410003093919933
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# ep %d: game finished, reward: %f 936 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.415903062980735
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# ep %d: game finished, reward: %f 937 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.42174403235093
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# ep %d: game finished, reward: %f 938 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.42752659202742
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# ep %d: game finished, reward: %f 939 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.433251326107147
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# ep %d: game finished, reward: %f 940 -1.0
# resetting env. episode reward total was %f. running mean: %f -19.0 -20.418918812846076
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# ep %d: game finished, reward: %f 941 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.414729624717616
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# ep %d: game finished, reward: %f 942 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.42058232847044
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# ep %d: game finished, reward: %f 943 -1.0
# resetting env. episode reward total was %f. running mean: %f -21.0 -20.426376505185736
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 1.0  !!!!!!!!
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# ep %d: game finished, reward: %f 944 -1.0
# resetting env. episode reward total was %f. running mean: %f -20.0 -20.422112740133876
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
# ep %d: game finished, reward: %f 945 -1.0
